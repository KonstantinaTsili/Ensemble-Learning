# %% [markdown]
# # Set-ups & Import Data

# %%
! pip install kaggle

! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

! chmod 600 ~/.kaggle/kaggle.json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.8/dist-packages (1.5.12)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.8/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.26.14)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.25.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from kaggle) (4.64.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.8/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (4.0.0)

# %%
# !kaggle datasets download -d dgomonov/new-york-city-airbnb-open-data
# Out:
# Downloading new-york-city-airbnb-open-data.zip to /content
#  82% 2.00M/2.44M [00:01<00:00, 1.86MB/s]
# 100% 2.44M/2.44M [00:01<00:00, 1.91MB/s]

# %%
# !apt-get install unzip
# !unzip new-york-city-airbnb-open-data.zip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-25ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Archive:  new-york-city-airbnb-open-data.zip
#   inflating: AB_NYC_2019.csv
#   inflating: New_York_City_.png

# %% [markdown]
# # Data Preprocessing (standardized)

# %%
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
matplotlib.rcParams['font.family'] = "Arial"

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly as py
import plotly.graph_objs as go
from plotly.subplots import make_subplots

init_notebook_mode(connected=True)

import collections
import itertools

import scipy.stats as stats
from scipy.stats import norm
from scipy.special import boxcox1p

import statsmodels
import statsmodels.api as sm
#print(statsmodels.__version__)

from sklearn.preprocessing import scale, StandardScaler, RobustScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold, StratifiedKFold, RandomizedSearchCV
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV, LinearRegression, ElasticNet,  HuberRegressor
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.kernel_ridge import KernelRidge
from sklearn.utils import resample

from xgboost import XGBRegressor

#Model interpretation modules
#mport eli5
#import lime
#import lime.lime_tabular
#import shap
#shap.initjs()

#import warnings
#warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('/content/AB_NYC_2019.csv')
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
print('Number of features: {}'.format(data.shape[1]))
print('Number of examples: {}'.format(data.shape[0]))
# Out:
# Number of features: 16
# Number of examples: 48895

# %%
#datetime transformation
data['last_review'] = pd.to_datetime(data['last_review'],infer_datetime_format=True)

# %%
#checking null values
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum())/data.isnull().count().sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total','Percent'], sort=False).sort_values('Total', ascending=False)
missing_data.head(40)
# Out:
#                                 Total   Percent
# last_review                     10052  0.205583
# reviews_per_month               10052  0.205583
# host_name                          21  0.000429
# name                               16  0.000327
# id                                  0  0.000000
# host_id                             0  0.000000
# neighbourhood_group                 0  0.000000
# neighbourhood                       0  0.000000
# latitude                            0  0.000000
# longitude                           0  0.000000
# room_type                           0  0.000000
# price                               0  0.000000
# minimum_nights                      0  0.000000
# number_of_reviews                   0  0.000000
# calculated_host_listings_count      0  0.000000
# availability_365                    0  0.000000

# %%
#drop useless columns
data.drop(['host_name','name'], axis=1, inplace=True)
data[data['number_of_reviews']== 0.0].shape
# Out:
# (10052, 14)

# %%
#Creating that binary column (new listing : Yes/No)
data["new_listing"] = 0
data["new_listing"][data["last_review"].isnull()] = 1

# %%
data['reviews_per_month'] = data['reviews_per_month'].fillna(0)

earliest = min(data['last_review'])
data['last_review'] = data['last_review'].fillna(earliest)
data['review_recency'] = (data.last_review.max() - data.last_review).dt.days
#data['last_review'] = data['last_review'].apply(lambda x: x.toordinal() - earliest.toordinal())

# %%
#transform numerical values to categorical ones
#because of unbalanced distribution

#data['minimum_nights'] = np.log1p(data['minimum_nights'])
data['all_year_avail'] = data['availability_365']>350
data['low_avail'] = data['availability_365']< 12

#data['reviews_per_month'] = data[data['reviews_per_month'] < 17.5]['reviews_per_month']
#data['no_reviews'] = data['reviews_per_month']==0
#data['reviews_per_month'] = data['reviews_per_month'].fillna(0)

data['months'] = data['number_of_reviews']/data['reviews_per_month']
data['months'] = data['months'].fillna(0)

# %%
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum())/data.isnull().count().sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total','Percent'], sort=False).sort_values('Total', ascending=False)
missing_data.head(40)
# Out:
#                                 Total  Percent
# id                                  0      0.0
# host_id                             0      0.0
# neighbourhood_group                 0      0.0
# neighbourhood                       0      0.0
# latitude                            0      0.0
# longitude                           0      0.0
# room_type                           0      0.0
# price                               0      0.0
# minimum_nights                      0      0.0
# number_of_reviews                   0      0.0
# last_review                         0      0.0
# reviews_per_month                   0      0.0
# calculated_host_listings_count      0      0.0
# availability_365                    0      0.0
# new_listing                         0      0.0
# review_recency                      0      0.0
# all_year_avail                      0      0.0
# low_avail                           0      0.0
# months                              0      0.0

# %%
data = data.drop(['host_id', 'id','last_review'], axis=1)

# %%
#one hot encoding room type & neighbourhood groups
data['type'] = 1
data_pivoted = data.pivot(columns='room_type',values='type').fillna(0)
data = data.join(data_pivoted)
data_pivoted = data.pivot(columns='neighbourhood_group',values='type').fillna(0)
data = data.join(data_pivoted)
data = data.drop(columns=['type','room_type','neighbourhood_group'])

#transform categorical neighbourhood into numeric ones
data['neighbourhood_numeric'] = pd.factorize(data['neighbourhood'])[0]
data = data.drop(columns=['neighbourhood'])

# %%
data.columns
# Out:
# Index(['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'new_listing', 'review_recency', 'all_year_avail',
#        'low_avail', 'months', 'Entire home/apt', 'Private room', 'Shared room',
#        'Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'neighbourhood_numeric'],
#       dtype='object')

# %%
#one_hot_encoding for categorical features

#print('Categorical features: {}'.format(categorical_features.shape))
#categorical_features_one_hot = pd.get_dummies(categorical_features)
#categorical_features_one_hot.head()

# %%
#numerical_features =  data.select_dtypes(exclude=['object'])
#y = numerical_features.price 
#y = np.log(numerical_features.price + 1)
#numerical_features = numerical_features.drop(['price'], axis=1)
#print('Numerical features: {}'.format(numerical_features.shape))

# %%
#X = np.concatenate((numerical_features, categorical_features_one_hot), axis=1)
#X_df = pd.concat([numerical_features, categorical_features_one_hot], axis=1)
Processed_data = data
Processed_data
Processed_data.to_csv('NYC_Airbnb_Processed.dat')

# %%
y = np.log(data.price + 1)
X = data.drop('price', axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
print('Dimensions of the training feature matrix: {}'.format(X_train.shape))
print('Dimensions of the training target vector: {}'.format(y_train.shape))
print('Dimensions of the test feature matrix: {}'.format(X_test.shape))
print('Dimensions of the test target vector: {}'.format(y_test.shape))
# Out:
# Dimensions of the training feature matrix: (39116, 21)
# Dimensions of the training target vector: (39116,)
# Dimensions of the test feature matrix: (9779, 21)
# Dimensions of the test target vector: (9779,)

# %%
#scaler = RobustScaler()
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.fit_transform(X_test)

# %% [markdown]
# # XGBoost

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
from datetime import datetime
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score


# import packages for hyperparameters tuning
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
n_folds = 5

# squared_loss
def rmse_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state = 0)
    return cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=kf)

def rmse(actual,predicted):
    return(np.sqrt(mean_squared_error(actual, predicted)))

def model_scores(model, cv_model, y_train, y_test, pred_train, pred_test):
    mse = mean_squared_error(y_test, pred_test)
    results = pd.DataFrame({'Model':['{}'.format(type(model).__name__)],
                'CV error': '{:.3f}'.format(cv_model.mean()), 
                'CV std': '{:.3f}'.format(cv_model.std()),
                'RMSE train': [rmse(y_train, pred_train)],
                'RMSE test': [rmse(y_test, pred_test)],
                'R2 train': [r2_score(y_train, pred_train)],
                'R2 test': [r2_score(y_test, pred_test)]})
    results = results.round(decimals=4)

    return results

def model_scores_log(model, cv_model, y_train, y_test, pred_train, pred_test):
    mse = mean_squared_error(y_test, pred_test)
    results = pd.DataFrame({'Model':['{}'.format(type(model).__name__)],
                'CV error': '{:.3f}'.format(np.exp(cv_model.mean())), 
                'CV std': '{:.3f}'.format(np.exp(cv_model.std())),
                'RMSE train': [rmse((np.exp(y_train)-1), (np.exp(pred_train)-1))],
                'RMSE test': [rmse((np.exp(y_test)-1), (np.exp(pred_test)-1))],
                'R2 train': [r2_score((np.exp(y_train)-1), (np.exp(pred_train)-1))],
                'R2 test': [r2_score((np.exp(y_test)-1), (np.exp(pred_test)-1))]})
    results = results.round(decimals=4)

    return results

# %% [markdown]
# ## baseline model

# %%
xbgreg_best = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5, min_child_weight=1)
xbgreg_CV_best = -rmse_cv(xbgreg_best)
xbgreg_best.fit(X_train, y_train, early_stopping_rounds=10,eval_set=[(X_test, y_test)], verbose=False) 
y_train_xgbreg = xbgreg_best.predict(X_train)
y_test_xgbreg = xbgreg_best.predict(X_test)

xgb_best_results_log = model_scores(xbgreg_best, xbgreg_CV_best, y_train, y_test, y_train_xgbreg, y_test_xgbreg)
xgb_best_results_back = model_scores_log(xbgreg_best, xbgreg_CV_best, y_train, y_test, y_train_xgbreg, y_test_xgbreg)

# %%
xgb_best_results_log.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_59680_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >CV error</th>
#       <th class="col_heading level0 col2" >CV std</th>
#       <th class="col_heading level0 col3" >RMSE train</th>
#       <th class="col_heading level0 col4" >RMSE test</th>
#       <th class="col_heading level0 col5" >R2 train</th>
#       <th class="col_heading level0 col6" >R2 test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_59680_row0_col0" class="data row0 col0" >XGBRegressor</td>
#       <td id="T_59680_row0_col1" class="data row0 col1" >0.193</td>
#       <td id="T_59680_row0_col2" class="data row0 col2" >0.008</td>
#       <td id="T_59680_row0_col3" class="data row0 col3" >0.418300</td>
#       <td id="T_59680_row0_col4" class="data row0 col4" >0.440300</td>
#       <td id="T_59680_row0_col5" class="data row0 col5" >0.636400</td>
#       <td id="T_59680_row0_col6" class="data row0 col6" >0.606000</td>
#     </tr>
#   </tbody>
# </table>

# %%
xgb_best_results_back.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_fd8ee_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >CV error</th>
#       <th class="col_heading level0 col2" >CV std</th>
#       <th class="col_heading level0 col3" >RMSE train</th>
#       <th class="col_heading level0 col4" >RMSE test</th>
#       <th class="col_heading level0 col5" >R2 train</th>
#       <th class="col_heading level0 col6" >R2 test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fd8ee_row0_col0" class="data row0 col0" >XGBRegressor</td>
#       <td id="T_fd8ee_row0_col1" class="data row0 col1" >1.213</td>
#       <td id="T_fd8ee_row0_col2" class="data row0 col2" >1.008</td>
#       <td id="T_fd8ee_row0_col3" class="data row0 col3" >217.183300</td>
#       <td id="T_fd8ee_row0_col4" class="data row0 col4" >215.446400</td>
#       <td id="T_fd8ee_row0_col5" class="data row0 col5" >0.191400</td>
#       <td id="T_fd8ee_row0_col6" class="data row0 col6" >0.156600</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## hyperparameter-tuning : GridSearchCV

# %%
# A parameter grid for XGBoost
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0, 0.5, 0.7, 1, 1.5],
        #'subsample': [0.6, 0.8, 1.0],
        #'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [5, 10, 15],
        'n_estimators':range(70,100,10),
        'learning_rate': [0.1, 0.05, 0.01]
        }

# %%
estimator = XGBRegressor(n_estimators = 100)

grid_search = GridSearchCV(
    estimator=estimator,
    param_grid=params,
    scoring = 'r2',
    #n_jobs = 5,
    cv = 5,
    verbose=10
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 405 candidates, totalling 2025 fits
# [CV 1/5; 1/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=70
# [CV 1/5; 1/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=70;, score=0.585 total time=   4.7s
# [CV 2/5; 1/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=70
# [CV 2/5; 1/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=70;, score=0.599 total time=   3.4s
# [CV 3/5; 1/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=70
# [CV 3/5; 1/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=70;, score=0.596 total time=   3.4s
# [CV 4/5; 1/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=70
# [CV 4/5; 1/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=70;, score=0.593 total time=   4.8s
# [CV 5/5; 1/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=70
# [CV 5/5; 1/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=70;, score=0.596 total time=   3.4s
# [CV 1/5; 2/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=80
# [CV 1/5; 2/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=80;, score=0.585 total time=   3.7s
# [CV 2/5; 2/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=80
# [CV 2/5; 2/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=80;, score=0.600 total time=   5.2s
# [CV 3/5; 2/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=80
# [CV 3/5; 2/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=80;, score=0.597 total time=   3.7s
# [CV 4/5; 2/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=80
# [CV 4/5; 2/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=80;, score=0.594 total time=   3.8s
# [CV 5/5; 2/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=80
# [CV 5/5; 2/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=80;, score=0.597 total time=   5.2s
# [CV 1/5; 3/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=90
# [CV 1/5; 3/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=90;, score=0.586 total time=   4.2s
# [CV 2/5; 3/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=90
# [CV 2/5; 3/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=90;, score=0.601 total time=   4.1s
# [CV 3/5; 3/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=90
# [CV 3/5; 3/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=90;, score=0.598 total time=   5.5s
# [CV 4/5; 3/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=90
# [CV 4/5; 3/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=90;, score=0.596 total time=   4.2s
# [CV 5/5; 3/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=90
# [CV 5/5; 3/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=90;, score=0.598 total time=   5.5s
# [CV 1/5; 4/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=70
# [CV 1/5; 4/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=70;, score=0.584 total time=   3.4s
# [CV 2/5; 4/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=70
# [CV 2/5; 4/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=70;, score=0.601 total time=   3.4s
# [CV 3/5; 4/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=70
# [CV 3/5; 4/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=70;, score=0.595 total time=   4.7s
# [CV 4/5; 4/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=70
# [CV 4/5; 4/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=70;, score=0.591 total time=   3.4s
# [CV 5/5; 4/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=70
# [CV 5/5; 4/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=70;, score=0.597 total time=   3.4s
# [CV 1/5; 5/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=80
# [CV 1/5; 5/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=80;, score=0.585 total time=   3.9s
# [CV 2/5; 5/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=80
# [CV 2/5; 5/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=80;, score=0.602 total time=   4.4s
# [CV 3/5; 5/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=80
# [CV 3/5; 5/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=80;, score=0.596 total time=   3.7s
# [CV 4/5; 5/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=80
# [CV 4/5; 5/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=80;, score=0.592 total time=   4.0s
# [CV 5/5; 5/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=80
# [CV 5/5; 5/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=80;, score=0.598 total time=   4.3s
# [CV 1/5; 6/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=90
# [CV 1/5; 6/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=90;, score=0.586 total time=   4.1s
# [CV 2/5; 6/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=90
# [CV 2/5; 6/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=90;, score=0.603 total time=   5.3s
# [CV 3/5; 6/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=90
# [CV 3/5; 6/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=90;, score=0.598 total time=   4.2s
# [CV 4/5; 6/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=90
# [CV 4/5; 6/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=90;, score=0.593 total time=   4.1s
# [CV 5/5; 6/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=90
# [CV 5/5; 6/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=90;, score=0.599 total time=   5.5s
# [CV 1/5; 7/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=70
# [CV 1/5; 7/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=70;, score=0.584 total time=   3.4s
# [CV 2/5; 7/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=70
# [CV 2/5; 7/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=70;, score=0.601 total time=   3.4s
# [CV 3/5; 7/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=70
# [CV 3/5; 7/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=70;, score=0.593 total time=   4.7s
# [CV 4/5; 7/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=70
# [CV 4/5; 7/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=70;, score=0.589 total time=   3.3s
# [CV 5/5; 7/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=70
# [CV 5/5; 7/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=70;, score=0.598 total time=   3.4s
# [CV 1/5; 8/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=80
# [CV 1/5; 8/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=80;, score=0.585 total time=   5.2s
# [CV 2/5; 8/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=80
# [CV 2/5; 8/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=80;, score=0.602 total time=   3.7s
# [CV 3/5; 8/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=80
# [CV 3/5; 8/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=80;, score=0.594 total time=   3.7s
# [CV 4/5; 8/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=80
# [CV 4/5; 8/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=80;, score=0.591 total time=   5.1s
# [CV 5/5; 8/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=80
# [CV 5/5; 8/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=80;, score=0.600 total time=   3.8s
# [CV 1/5; 9/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=90
# [CV 1/5; 9/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=90;, score=0.586 total time=   4.2s
# [CV 2/5; 9/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=90
# [CV 2/5; 9/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=90;, score=0.603 total time=   5.5s
# [CV 3/5; 9/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=90
# [CV 3/5; 9/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=90;, score=0.595 total time=   4.2s
# [CV 4/5; 9/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=90
# [CV 4/5; 9/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=90;, score=0.592 total time=   5.4s
# [CV 5/5; 9/405] START gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=90
# [CV 5/5; 9/405] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=90;, score=0.601 total time=   4.2s
# [CV 1/5; 10/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=70
# [CV 1/5; 10/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=70;, score=0.591 total time=   6.3s
# [CV 2/5; 10/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=70
# [CV 2/5; 10/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=70;, score=0.616 total time=   6.9s
# [CV 3/5; 10/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=70
# [CV 3/5; 10/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=70;, score=0.612 total time=   7.6s
# [CV 4/5; 10/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=70
# [CV 4/5; 10/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=70;, score=0.605 total time=   6.2s
# [CV 5/5; 10/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=70
# [CV 5/5; 10/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=70;, score=0.603 total time=   7.6s
# [CV 1/5; 11/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=80
# [CV 1/5; 11/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=80;, score=0.591 total time=   7.0s
# [CV 2/5; 11/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=80
# [CV 2/5; 11/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=80;, score=0.616 total time=   8.4s
# [CV 3/5; 11/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=80
# [CV 3/5; 11/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=80;, score=0.612 total time=   8.4s
# [CV 4/5; 11/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=80
# [CV 4/5; 11/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=80;, score=0.606 total time=   7.0s
# [CV 5/5; 11/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=80
# [CV 5/5; 11/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=80;, score=0.604 total time=   8.4s
# [CV 1/5; 12/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=90
# [CV 1/5; 12/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=90;, score=0.591 total time=   9.2s
# [CV 2/5; 12/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=90
# [CV 2/5; 12/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=90;, score=0.616 total time=   7.8s
# [CV 3/5; 12/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=90
# [CV 3/5; 12/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=90;, score=0.612 total time=   9.2s
# [CV 4/5; 12/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=90
# [CV 4/5; 12/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=90;, score=0.606 total time=   9.1s
# [CV 5/5; 12/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=90
# [CV 5/5; 12/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=90;, score=0.603 total time=   7.9s
# [CV 1/5; 13/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=70
# [CV 1/5; 13/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=70;, score=0.595 total time=   6.8s
# [CV 2/5; 13/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=70
# [CV 2/5; 13/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=70;, score=0.614 total time=   7.6s
# [CV 3/5; 13/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=70
# [CV 3/5; 13/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=70;, score=0.609 total time=   6.2s
# [CV 4/5; 13/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=70
# [CV 4/5; 13/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=70;, score=0.607 total time=   7.5s
# [CV 5/5; 13/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=70
# [CV 5/5; 13/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=70;, score=0.611 total time=   6.1s
# [CV 1/5; 14/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=80
# [CV 1/5; 14/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=80;, score=0.595 total time=   8.3s
# [CV 2/5; 14/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=80
# [CV 2/5; 14/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=80;, score=0.614 total time=   8.3s
# [CV 3/5; 14/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=80
# [CV 3/5; 14/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=80;, score=0.609 total time=   7.0s
# [CV 4/5; 14/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=80
# [CV 4/5; 14/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=80;, score=0.608 total time=   8.3s
# [CV 5/5; 14/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=80
# [CV 5/5; 14/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=80;, score=0.611 total time=   6.9s
# [CV 1/5; 15/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=90
# [CV 1/5; 15/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=90;, score=0.595 total time=   8.5s
# [CV 2/5; 15/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=90
# [CV 2/5; 15/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=90;, score=0.614 total time=   9.1s
# [CV 3/5; 15/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=90
# [CV 3/5; 15/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=90;, score=0.609 total time=   9.1s
# [CV 4/5; 15/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=90
# [CV 4/5; 15/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=90;, score=0.607 total time=   7.6s
# [CV 5/5; 15/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=90
# [CV 5/5; 15/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=90;, score=0.611 total time=   9.0s
# [CV 1/5; 16/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=70
# [CV 1/5; 16/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=70;, score=0.597 total time=   7.4s
# [CV 2/5; 16/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=70
# [CV 2/5; 16/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=70;, score=0.615 total time=   6.1s
# [CV 3/5; 16/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=70
# [CV 3/5; 16/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=70;, score=0.605 total time=   7.5s
# [CV 4/5; 16/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=70
# [CV 4/5; 16/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=70;, score=0.606 total time=   6.1s
# [CV 5/5; 16/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=70
# [CV 5/5; 16/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=70;, score=0.611 total time=   7.4s
# [CV 1/5; 17/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=80
# [CV 1/5; 17/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=80;, score=0.597 total time=   6.9s
# [CV 2/5; 17/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=80
# [CV 2/5; 17/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=80;, score=0.615 total time=   8.2s
# [CV 3/5; 17/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=80
# [CV 3/5; 17/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=80;, score=0.606 total time=   8.3s
# [CV 4/5; 17/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=80
# [CV 4/5; 17/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=80;, score=0.607 total time=   6.8s
# [CV 5/5; 17/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=80
# [CV 5/5; 17/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=80;, score=0.611 total time=   8.2s
# [CV 1/5; 18/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=90
# [CV 1/5; 18/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=90;, score=0.597 total time=   8.9s
# [CV 2/5; 18/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=90
# [CV 2/5; 18/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=90;, score=0.615 total time=   7.6s
# [CV 3/5; 18/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=90
# [CV 3/5; 18/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=90;, score=0.607 total time=   9.0s
# [CV 4/5; 18/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=90
# [CV 4/5; 18/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=90;, score=0.607 total time=   9.0s
# [CV 5/5; 18/405] START gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=90
# [CV 5/5; 18/405] END gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=90;, score=0.611 total time=   7.6s
# [CV 1/5; 19/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=70
# [CV 1/5; 19/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=70;, score=0.582 total time=  10.9s
# [CV 2/5; 19/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=70
# [CV 2/5; 19/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=70;, score=0.607 total time=  11.0s
# [CV 3/5; 19/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=70
# [CV 3/5; 19/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=70;, score=0.606 total time=  10.9s
# [CV 4/5; 19/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=70
# [CV 4/5; 19/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=70;, score=0.596 total time=  11.1s
# [CV 5/5; 19/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=70
# [CV 5/5; 19/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=70;, score=0.596 total time=  11.0s
# [CV 1/5; 20/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=80
# [CV 1/5; 20/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=80;, score=0.581 total time=  12.2s
# [CV 2/5; 20/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=80
# [CV 2/5; 20/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=80;, score=0.606 total time=  12.1s
# [CV 3/5; 20/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=80
# [CV 3/5; 20/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=80;, score=0.605 total time=  12.1s
# [CV 4/5; 20/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=80
# [CV 4/5; 20/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=80;, score=0.596 total time=  12.2s
# [CV 5/5; 20/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=80
# [CV 5/5; 20/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=80;, score=0.595 total time=  12.2s
# [CV 1/5; 21/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=90
# [CV 1/5; 21/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=90;, score=0.581 total time=  13.4s
# [CV 2/5; 21/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=90
# [CV 2/5; 21/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=90;, score=0.606 total time=  13.4s
# [CV 3/5; 21/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=90
# [CV 3/5; 21/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=90;, score=0.605 total time=  13.5s
# [CV 4/5; 21/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=90
# [CV 4/5; 21/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=90;, score=0.596 total time=  13.5s
# [CV 5/5; 21/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=90
# [CV 5/5; 21/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=90;, score=0.594 total time=  13.4s
# [CV 1/5; 22/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=70
# [CV 1/5; 22/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=70;, score=0.590 total time=  10.3s
# [CV 2/5; 22/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=70
# [CV 2/5; 22/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=70;, score=0.610 total time=  10.1s
# [CV 3/5; 22/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=70
# [CV 3/5; 22/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=70;, score=0.603 total time=  10.2s
# [CV 4/5; 22/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=70
# [CV 4/5; 22/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=70;, score=0.603 total time=  10.2s
# [CV 5/5; 22/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=70
# [CV 5/5; 22/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=70;, score=0.604 total time=   8.9s
# [CV 1/5; 23/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=80
# [CV 1/5; 23/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=80;, score=0.591 total time=  11.4s
# [CV 2/5; 23/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=80
# [CV 2/5; 23/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=80;, score=0.610 total time=  11.4s
# [CV 3/5; 23/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=80
# [CV 3/5; 23/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=80;, score=0.603 total time=  11.4s
# [CV 4/5; 23/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=80
# [CV 4/5; 23/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=80;, score=0.603 total time=  11.4s
# [CV 5/5; 23/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=80
# [CV 5/5; 23/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=80;, score=0.604 total time=  11.4s
# [CV 1/5; 24/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=90
# [CV 1/5; 24/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=90;, score=0.590 total time=  12.6s
# [CV 2/5; 24/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=90
# [CV 2/5; 24/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=90;, score=0.610 total time=  12.6s
# [CV 3/5; 24/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=90
# [CV 3/5; 24/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=90;, score=0.602 total time=  12.5s
# [CV 4/5; 24/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=90
# [CV 4/5; 24/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=90;, score=0.603 total time=  12.6s
# [CV 5/5; 24/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=90
# [CV 5/5; 24/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=5, n_estimators=90;, score=0.604 total time=  12.6s
# [CV 1/5; 25/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=70
# [CV 1/5; 25/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=70;, score=0.596 total time=  10.0s
# [CV 2/5; 25/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=70
# [CV 2/5; 25/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=70;, score=0.611 total time=  10.1s
# [CV 3/5; 25/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=70
# [CV 3/5; 25/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=70;, score=0.603 total time=  10.1s
# [CV 4/5; 25/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=70
# [CV 4/5; 25/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=70;, score=0.603 total time=   8.7s
# [CV 5/5; 25/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=70
# [CV 5/5; 25/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=70;, score=0.607 total time=  10.0s
# [CV 1/5; 26/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=80
# [CV 1/5; 26/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=80;, score=0.597 total time=  11.1s
# [CV 2/5; 26/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=80
# [CV 2/5; 26/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=80;, score=0.611 total time=  11.2s
# [CV 3/5; 26/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=80
# [CV 3/5; 26/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=80;, score=0.604 total time=  11.3s
# [CV 4/5; 26/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=80
# [CV 4/5; 26/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=80;, score=0.604 total time=  11.2s
# [CV 5/5; 26/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=80
# [CV 5/5; 26/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=80;, score=0.608 total time=  11.1s
# [CV 1/5; 27/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=90
# [CV 1/5; 27/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=90;, score=0.596 total time=  12.3s
# [CV 2/5; 27/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=90
# [CV 2/5; 27/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=90;, score=0.611 total time=  12.4s
# [CV 3/5; 27/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=90
# [CV 3/5; 27/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=90;, score=0.604 total time=  12.4s
# [CV 4/5; 27/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=90
# [CV 4/5; 27/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=90;, score=0.604 total time=  12.4s
# [CV 5/5; 27/405] START gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=90
# [CV 5/5; 27/405] END gamma=0, learning_rate=0.1, max_depth=15, min_child_weight=10, n_estimators=90;, score=0.608 total time=  12.3s
# [CV 1/5; 28/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=70
# [CV 1/5; 28/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=70;, score=0.542 total time=   3.4s
# [CV 2/5; 28/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=70
# [CV 2/5; 28/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=70;, score=0.556 total time=   3.4s
# [CV 3/5; 28/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=70
# [CV 3/5; 28/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=70;, score=0.553 total time=   4.7s
# [CV 4/5; 28/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=70
# [CV 4/5; 28/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=70;, score=0.542 total time=   3.4s
# [CV 5/5; 28/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=70
# [CV 5/5; 28/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=70;, score=0.558 total time=   3.4s
# [CV 1/5; 29/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=80
# [CV 1/5; 29/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=80;, score=0.564 total time=   5.2s
# [CV 2/5; 29/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=80
# [CV 2/5; 29/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=80;, score=0.579 total time=   3.8s
# [CV 3/5; 29/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=80
# [CV 3/5; 29/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=80;, score=0.576 total time=   3.8s
# [CV 4/5; 29/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=80
# [CV 4/5; 29/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=80;, score=0.567 total time=   5.2s
# [CV 5/5; 29/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=80
# [CV 5/5; 29/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=80;, score=0.580 total time=   3.8s
# [CV 1/5; 30/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=90
# [CV 1/5; 30/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=90;, score=0.574 total time=   4.2s
# [CV 2/5; 30/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=90
# [CV 2/5; 30/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=90;, score=0.588 total time=   5.5s
# [CV 3/5; 30/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=90
# [CV 3/5; 30/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=90;, score=0.585 total time=   4.1s
# [CV 4/5; 30/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=90
# [CV 4/5; 30/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=90;, score=0.579 total time=   5.3s
# [CV 5/5; 30/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=90
# [CV 5/5; 30/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=90;, score=0.588 total time=   4.2s
# [CV 1/5; 31/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=70
# [CV 1/5; 31/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=70;, score=0.543 total time=   3.4s
# [CV 2/5; 31/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=70
# [CV 2/5; 31/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=70;, score=0.556 total time=   4.6s
# [CV 3/5; 31/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=70
# [CV 3/5; 31/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=70;, score=0.551 total time=   3.4s
# [CV 4/5; 31/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=70
# [CV 4/5; 31/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=70;, score=0.541 total time=   3.4s
# [CV 5/5; 31/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=70
# [CV 5/5; 31/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=70;, score=0.559 total time=   3.4s
# [CV 1/5; 32/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=80
# [CV 1/5; 32/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=80;, score=0.565 total time=   4.5s
# [CV 2/5; 32/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=80
# [CV 2/5; 32/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=80;, score=0.579 total time=   3.8s
# [CV 3/5; 32/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=80
# [CV 3/5; 32/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=80;, score=0.573 total time=   3.9s
# [CV 4/5; 32/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=80
# [CV 4/5; 32/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=80;, score=0.566 total time=   4.5s
# [CV 5/5; 32/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=80
# [CV 5/5; 32/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=80;, score=0.580 total time=   3.7s
# [CV 1/5; 33/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=90
# [CV 1/5; 33/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=90;, score=0.575 total time=   5.5s
# [CV 2/5; 33/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=90
# [CV 2/5; 33/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=90;, score=0.589 total time=   4.1s
# [CV 3/5; 33/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=90
# [CV 3/5; 33/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=90;, score=0.583 total time=   4.2s
# [CV 4/5; 33/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=90
# [CV 4/5; 33/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=90;, score=0.577 total time=   5.6s
# [CV 5/5; 33/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=90
# [CV 5/5; 33/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=90;, score=0.589 total time=   4.1s
# [CV 1/5; 34/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=70
# [CV 1/5; 34/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=70;, score=0.543 total time=   3.4s
# [CV 2/5; 34/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=70
# [CV 2/5; 34/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=70;, score=0.556 total time=   4.7s
# [CV 3/5; 34/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=70
# [CV 3/5; 34/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=70;, score=0.551 total time=   3.4s
# [CV 4/5; 34/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=70
# [CV 4/5; 34/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=70;, score=0.541 total time=   3.4s
# [CV 5/5; 34/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=70
# [CV 5/5; 34/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=70;, score=0.559 total time=   4.8s
# [CV 1/5; 35/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=80
# [CV 1/5; 35/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=80;, score=0.565 total time=   3.8s
# [CV 2/5; 35/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=80
# [CV 2/5; 35/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=80;, score=0.579 total time=   3.8s
# [CV 3/5; 35/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=80
# [CV 3/5; 35/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=80;, score=0.573 total time=   5.2s
# [CV 4/5; 35/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=80
# [CV 4/5; 35/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=80;, score=0.566 total time=   3.8s
# [CV 5/5; 35/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=80
# [CV 5/5; 35/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=80;, score=0.580 total time=   3.8s
# [CV 1/5; 36/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=90
# [CV 1/5; 36/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=90;, score=0.575 total time=   5.6s
# [CV 2/5; 36/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=90
# [CV 2/5; 36/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=90;, score=0.589 total time=   4.2s
# [CV 3/5; 36/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=90
# [CV 3/5; 36/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=90;, score=0.582 total time=   5.5s
# [CV 4/5; 36/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=90
# [CV 4/5; 36/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=90;, score=0.578 total time=   4.2s
# [CV 5/5; 36/405] START gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=90
# [CV 5/5; 36/405] END gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=10, n_estimators=90;, score=0.589 total time=   4.1s
# [CV 1/5; 37/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=70
# [CV 1/5; 37/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=70;, score=0.561 total time=   7.6s
# [CV 2/5; 37/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=70
# [CV 2/5; 37/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=70;, score=0.583 total time=   6.3s
# [CV 3/5; 37/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=70
# [CV 3/5; 37/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=70;, score=0.579 total time=   7.2s
# [CV 4/5; 37/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=70
# [CV 4/5; 37/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=70;, score=0.565 total time=   7.7s
# [CV 5/5; 37/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=70
# [CV 5/5; 37/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=70;, score=0.574 total time=   6.3s
# [CV 1/5; 38/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=80
# [CV 1/5; 38/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=80;, score=0.582 total time=   8.5s
# [CV 2/5; 38/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=80
# [CV 2/5; 38/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=80;, score=0.605 total time=   7.0s
# [CV 3/5; 38/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=80
# [CV 3/5; 38/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=80;, score=0.599 total time=   7.8s
# [CV 4/5; 38/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=80
# [CV 4/5; 38/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=80;, score=0.588 total time=   8.5s
# [CV 5/5; 38/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=80
# [CV 5/5; 38/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=80;, score=0.593 total time=   7.1s
# [CV 1/5; 39/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=90
# [CV 1/5; 39/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=90;, score=0.590 total time=   9.2s
# [CV 2/5; 39/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=90
# [CV 2/5; 39/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=90;, score=0.612 total time=   9.3s
# [CV 3/5; 39/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=90
# [CV 3/5; 39/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=90;, score=0.607 total time=   9.3s
# [CV 4/5; 39/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=90
# [CV 4/5; 39/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=90;, score=0.599 total time=   7.9s
# [CV 5/5; 39/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=90
# [CV 5/5; 39/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=90;, score=0.600 total time=   9.3s
# [CV 1/5; 40/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=70
# [CV 1/5; 40/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=70;, score=0.560 total time=   7.6s
# [CV 2/5; 40/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=70
# [CV 2/5; 40/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=70;, score=0.581 total time=   6.2s
# [CV 3/5; 40/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=70
# [CV 3/5; 40/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=70;, score=0.576 total time=   7.6s
# [CV 4/5; 40/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=70
# [CV 4/5; 40/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=70;, score=0.564 total time=   6.2s
# [CV 5/5; 40/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=70
# [CV 5/5; 40/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=70;, score=0.578 total time=   7.5s
# [CV 1/5; 41/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=80
# [CV 1/5; 41/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=80;, score=0.581 total time=   8.4s
# [CV 2/5; 41/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=80
# [CV 2/5; 41/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=80;, score=0.602 total time=   6.9s
# [CV 3/5; 41/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=80
# [CV 3/5; 41/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=80;, score=0.597 total time=   8.4s
# [CV 4/5; 41/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=80
# [CV 4/5; 41/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=80;, score=0.588 total time=   7.7s
# [CV 5/5; 41/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=80
# [CV 5/5; 41/405] END gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=80;, score=0.598 total time=   7.2s
# [CV 1/5; 42/405] START gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=90
# ...
# [CV 1/5; 394/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=70
# [CV 1/5; 394/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=70;, score=-8.553 total time=   5.4s
# [CV 2/5; 394/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=70
# [CV 2/5; 394/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=70;, score=-8.768 total time=   7.1s
# [CV 3/5; 394/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=70
# [CV 3/5; 394/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=70;, score=-8.654 total time=   5.5s
# [CV 4/5; 394/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=70
# [CV 4/5; 394/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=70;, score=-8.686 total time=   6.4s
# [CV 5/5; 394/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=70
# [CV 5/5; 394/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=70;, score=-9.053 total time=   5.4s
# [CV 1/5; 395/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=80
# [CV 1/5; 395/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=80;, score=-6.899 total time=   7.1s
# [CV 2/5; 395/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=80
# [CV 2/5; 395/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=80;, score=-7.069 total time=   6.1s
# [CV 3/5; 395/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=80
# [CV 3/5; 395/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=80;, score=-6.978 total time=   7.2s
# [CV 4/5; 395/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=80
# [CV 4/5; 395/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=80;, score=-7.015 total time=   7.1s
# [CV 5/5; 395/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=80
# [CV 5/5; 395/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=80;, score=-7.296 total time=   6.2s
# [CV 1/5; 396/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=90
# [CV 1/5; 396/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=90;, score=-5.544 total time=   7.9s
# [CV 2/5; 396/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=90
# [CV 2/5; 396/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=90;, score=-5.680 total time=   6.9s
# [CV 3/5; 396/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=90
# [CV 3/5; 396/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=90;, score=-5.605 total time=   8.0s
# [CV 4/5; 396/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=90
# [CV 4/5; 396/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=90;, score=-5.646 total time=   7.9s
# [CV 5/5; 396/405] START gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=90
# [CV 5/5; 396/405] END gamma=1.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=90;, score=-5.859 total time=   7.0s
# [CV 1/5; 397/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=70
# [CV 1/5; 397/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=70;, score=-8.554 total time=   6.6s
# [CV 2/5; 397/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=70
# [CV 2/5; 397/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=70;, score=-8.767 total time=   5.6s
# [CV 3/5; 397/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=70
# [CV 3/5; 397/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=70;, score=-8.656 total time=   6.7s
# [CV 4/5; 397/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=70
# [CV 4/5; 397/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=70;, score=-8.687 total time=   6.0s
# [CV 5/5; 397/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=70
# [CV 5/5; 397/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=70;, score=-9.058 total time=   6.1s
# [CV 1/5; 398/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=80
# [CV 1/5; 398/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=80;, score=-6.900 total time=   7.6s
# [CV 2/5; 398/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=80
# [CV 2/5; 398/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=80;, score=-7.069 total time=   6.5s
# [CV 3/5; 398/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=80
# [CV 3/5; 398/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=80;, score=-6.979 total time=   7.5s
# [CV 4/5; 398/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=80
# [CV 4/5; 398/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=80;, score=-7.016 total time=   6.9s
# [CV 5/5; 398/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=80
# [CV 5/5; 398/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=80;, score=-7.301 total time=   7.2s
# [CV 1/5; 399/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=90
# [CV 1/5; 399/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=90;, score=-5.547 total time=   8.6s
# [CV 2/5; 399/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=90
# [CV 2/5; 399/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=90;, score=-5.679 total time=   7.5s
# [CV 3/5; 399/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=90
# [CV 3/5; 399/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=90;, score=-5.607 total time=   7.9s
# [CV 4/5; 399/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=90
# [CV 4/5; 399/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=90;, score=-5.647 total time=   8.7s
# [CV 5/5; 399/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=90
# [CV 5/5; 399/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=90;, score=-5.864 total time=   8.8s
# [CV 1/5; 400/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=70
# [CV 1/5; 400/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=70;, score=-8.554 total time=   5.6s
# [CV 2/5; 400/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=70
# [CV 2/5; 400/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=70;, score=-8.768 total time=   6.3s
# [CV 3/5; 400/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=70
# [CV 3/5; 400/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=70;, score=-8.655 total time=   5.5s
# [CV 4/5; 400/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=70
# [CV 4/5; 400/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=70;, score=-8.686 total time=   6.5s
# [CV 5/5; 400/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=70
# [CV 5/5; 400/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=70;, score=-9.054 total time=   5.6s
# [CV 1/5; 401/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=80
# [CV 1/5; 401/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=80;, score=-6.900 total time=   7.4s
# [CV 2/5; 401/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=80
# [CV 2/5; 401/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=80;, score=-7.069 total time=   6.3s
# [CV 3/5; 401/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=80
# [CV 3/5; 401/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=80;, score=-6.979 total time=   7.2s
# [CV 4/5; 401/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=80
# [CV 4/5; 401/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=80;, score=-7.015 total time=   7.5s
# [CV 5/5; 401/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=80
# [CV 5/5; 401/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=80;, score=-7.297 total time=   6.5s
# [CV 1/5; 402/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=90
# [CV 1/5; 402/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=90;, score=-5.546 total time=   8.3s
# [CV 2/5; 402/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=90
# [CV 2/5; 402/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=90;, score=-5.679 total time=   7.2s
# [CV 3/5; 402/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=90
# [CV 3/5; 402/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=90;, score=-5.606 total time=   7.6s
# [CV 4/5; 402/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=90
# [CV 4/5; 402/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=90;, score=-5.646 total time=   8.4s
# [CV 5/5; 402/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=90
# [CV 5/5; 402/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=5, n_estimators=90;, score=-5.860 total time=   7.8s
# [CV 1/5; 403/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=70
# [CV 1/5; 403/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=70;, score=-8.553 total time=   5.6s
# [CV 2/5; 403/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=70
# [CV 2/5; 403/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=70;, score=-8.768 total time=   5.6s
# [CV 3/5; 403/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=70
# [CV 3/5; 403/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=70;, score=-8.654 total time=   5.6s
# [CV 4/5; 403/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=70
# [CV 4/5; 403/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=70;, score=-8.686 total time=   5.7s
# [CV 5/5; 403/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=70
# [CV 5/5; 403/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=70;, score=-9.053 total time=   5.8s
# [CV 1/5; 404/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=80
# [CV 1/5; 404/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=80;, score=-6.899 total time=   7.4s
# [CV 2/5; 404/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=80
# [CV 2/5; 404/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=80;, score=-7.069 total time=   6.2s
# [CV 3/5; 404/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=80
# [CV 3/5; 404/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=80;, score=-6.978 total time=   7.2s
# [CV 4/5; 404/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=80
# [CV 4/5; 404/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=80;, score=-7.015 total time=   6.5s
# [CV 5/5; 404/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=80
# [CV 5/5; 404/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=80;, score=-7.296 total time=   7.4s
# [CV 1/5; 405/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=90
# [CV 1/5; 405/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=90;, score=-5.545 total time=   9.1s
# [CV 2/5; 405/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=90
# [CV 2/5; 405/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=90;, score=-5.680 total time=   7.1s
# [CV 3/5; 405/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=90
# [CV 3/5; 405/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=90;, score=-5.605 total time=   8.1s
# [CV 4/5; 405/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=90
# [CV 4/5; 405/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=90;, score=-5.646 total time=   8.3s
# [CV 5/5; 405/405] START gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=90
# [CV 5/5; 405/405] END gamma=1.5, learning_rate=0.01, max_depth=15, min_child_weight=10, n_estimators=90;, score=-5.859 total time=   7.3s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              param_grid={'gamma': [0, 0.5, 0.7, 1, 1.5],
#                          'learning_rate': [0.1, 0.05, 0.01],
#                          'max_depth': [5, 10, 15],
#                          'min_child_weight': [1, 5, 10],
#                          'n_estimators': range(70, 100, 10)},
#              scoring='r2', verbose=10)

# %%
grid_search.best_params_
# Out:
# {'gamma': 0.7,
#  'learning_rate': 0.1,
#  'max_depth': 10,
#  'min_child_weight': 5,
#  'n_estimators': 90}

# %% [markdown]
# ## best model

# %%
xbgreg_best = XGBRegressor(n_estimators=90, learning_rate=0.1, max_depth=10, min_child_weight=5, gamma=0.7)
xbgreg_CV_best = -rmse_cv(xbgreg_best)
xbgreg_best.fit(X_train, y_train, early_stopping_rounds=10,eval_set=[(X_test, y_test)], verbose=False) 
y_train_xgbreg = xbgreg_best.predict(X_train)
y_test_xgbreg = xbgreg_best.predict(X_test)


xgb_best_results_log = model_scores(xbgreg_best, xbgreg_CV_best, y_train, y_test, y_train_xgbreg, y_test_xgbreg)
xgb_best_results_back = model_scores_log(xbgreg_best, xbgreg_CV_best, y_train, y_test, y_train_xgbreg, y_test_xgbreg)

xgb_best_results_log.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e151_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >CV error</th>
#       <th class="col_heading level0 col2" >CV std</th>
#       <th class="col_heading level0 col3" >RMSE train</th>
#       <th class="col_heading level0 col4" >RMSE test</th>
#       <th class="col_heading level0 col5" >R2 train</th>
#       <th class="col_heading level0 col6" >R2 test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5e151_row0_col0" class="data row0 col0" >XGBRegressor</td>
#       <td id="T_5e151_row0_col1" class="data row0 col1" >0.188</td>
#       <td id="T_5e151_row0_col2" class="data row0 col2" >0.008</td>
#       <td id="T_5e151_row0_col3" class="data row0 col3" >0.354600</td>
#       <td id="T_5e151_row0_col4" class="data row0 col4" >0.434600</td>
#       <td id="T_5e151_row0_col5" class="data row0 col5" >0.738700</td>
#       <td id="T_5e151_row0_col6" class="data row0 col6" >0.616200</td>
#     </tr>
#   </tbody>
# </table>

# %%
xgb_best_results_back.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_03bb8_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >CV error</th>
#       <th class="col_heading level0 col2" >CV std</th>
#       <th class="col_heading level0 col3" >RMSE train</th>
#       <th class="col_heading level0 col4" >RMSE test</th>
#       <th class="col_heading level0 col5" >R2 train</th>
#       <th class="col_heading level0 col6" >R2 test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_03bb8_row0_col0" class="data row0 col0" >XGBRegressor</td>
#       <td id="T_03bb8_row0_col1" class="data row0 col1" >1.207</td>
#       <td id="T_03bb8_row0_col2" class="data row0 col2" >1.008</td>
#       <td id="T_03bb8_row0_col3" class="data row0 col3" >193.252500</td>
#       <td id="T_03bb8_row0_col4" class="data row0 col4" >213.416100</td>
#       <td id="T_03bb8_row0_col5" class="data row0 col5" >0.359800</td>
#       <td id="T_03bb8_row0_col6" class="data row0 col6" >0.172500</td>
#     </tr>
#   </tbody>
# </table>
